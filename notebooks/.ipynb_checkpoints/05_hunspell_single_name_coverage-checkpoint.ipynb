# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("sqlite:///../data/names_results2.db")

# %%
# Total dataset size
total = pd.read_sql("SELECT COUNT(*) AS total FROM names", engine).iloc[0, 0]
print(f"Total names: {total:,}")
# Out:
# Total names: 727,352

# %%
# Filter for single-word names by checking there are no spaces
df_single_word = df[~df['name'].str.contains(r'\s')]

# Check the size of the filtered set
print(f"Single-word names: {len(df_single_word):,}")

# Optional: inspect the first few rows
df_single_word.head()
# Out:
# Single-word names: 571,654
#      name                        full_countries_distribution top_country  \
# 164  A*-I  {"Afghanistan": null, "Albania": null, "Algeri...      Kuwait
# 165  A*-J  {"Afghanistan": null, "Albania": null, "Algeri...      Kuwait
# 166   A*F  {"Afghanistan": null, "Albania": null, "Algeri...     Morocco
# 167   A*H  {"Afghanistan": null, "Albania": null, "Algeri...     Morocco
# 168  A*Hf  {"Afghanistan": null, "Albania": null, "Algeri...     Morocco
#
#     top_country_langs  top_country_prob  strong_top_country  agreement_score  \
# 164            ["ar"]             0.814                   1              NaN
# 165            ["ar"]             0.691                   0              NaN
# 166            ["ar"]             0.720                   1              NaN
# 167            ["ar"]             0.952                   1              NaN
# 168            ["ar"]             0.785                   1              NaN
#
#      n_models_used name_script name_latin  ... ethnicolr_prob  \
# 164              2       Latin       A*-I  ...       0.218131
# 165              2       Latin       A*-J  ...       0.214918
# 166              2       Latin        A*F  ...       0.160630
# 167              2       Latin        A*H  ...       0.198325
# 168              2       Latin       A*Hf  ...       0.191476
#
#                                       eth_distribution langdetect_lang  \
# 164  {"African": 0.0424, "British": 0.0217, "EastAs...              hu
# 165  {"African": 0.0236, "British": 0.0174, "EastAs...              hu
# 166  {"African": 0.0788, "British": 0.0309, "EastAs...              hu
# 167  {"African": 0.0292, "British": 0.0311, "EastAs...              hu
# 168  {"African": 0.038, "British": 0.0255, "EastAsi...              hu
#
#     langdetect_lang_name langdetect_prob  country_lang_comp  \
# 164            Hungarian          0.8571                  0
# 165            Hungarian          1.0000                  0
# 166            Hungarian          1.0000                  0
# 167            Hungarian          1.0000                  0
# 168            Hungarian          0.5714                  0
#
#      hunspell_orig_known  hunspell_latin_known  pysc_orig_known  \
# 164                    0                     0                0
# 165                    0                     0                0
# 166                    0                     0                0
# 167                    0                     0                0
# 168                    0                     0                0
#
#      pysc_latin_known
# 164                 0
# 165                 0
# 166                 0
# 167                 0
# 168                 0
#
# [5 rows x 21 columns]

# %%
import regex as re

# Pattern: only allow Unicode letters (covers accents + non-Latin scripts)
valid_name_pattern = re.compile(r'^\p{L}+$')

# Create a cleaned copy (DO NOT overwrite df_single_word)
df_single_word_clean = df_single_word[
    df_single_word["name"].apply(lambda x: bool(valid_name_pattern.match(x)) if isinstance(x, str) else False)
]

print(f"Clean single-word names: {len(df_single_word_clean):,}")

# Compare how many were removed
removed = len(df_single_word) - len(df_single_word_clean)
print(f"Removed entries: {removed:,}")

# Inspect results
df_single_word_clean.head()
# Out:
# Clean single-word names: 556,400
# Removed entries: 15,254
#       name                        full_countries_distribution   top_country  \
# 228     Aa  {"Afghanistan": null, "Albania": null, "Algeri...       Morocco
# 229    Aaa  {"Afghanistan": null, "Albania": null, "Algeri...       Morocco
# 230    Aab  {"Afghanistan": null, "Albania": null, "Algeri...  Saudi Arabia
# 231   Aaba  {"Afghanistan": null, "Albania": null, "Algeri...         India
# 232  Aabah  {"Afghanistan": null, "Albania": null, "Algeri...  Saudi Arabia
#
#     top_country_langs  top_country_prob  strong_top_country  agreement_score  \
# 228            ["ar"]             0.626                   0              NaN
# 229            ["ar"]             0.694                   0              NaN
# 230            ["ar"]             0.330                   0              NaN
# 231      ["hi", "en"]             0.563                   0              NaN
# 232            ["ar"]             0.429                   0              NaN
#
#      n_models_used name_script name_latin  ... ethnicolr_prob  \
# 228              2       Latin         Aa  ...       0.731642
# 229              2       Latin        Aaa  ...       0.479951
# 230              2       Latin        Aab  ...       0.281341
# 231              2       Latin       Aaba  ...       0.217758
# 232              2       Latin      Aabah  ...       0.410527
#
#                                       eth_distribution langdetect_lang  \
# 228  {"African": 0.0057, "British": 0.0276, "EastAs...              so
# 229  {"African": 0.0006, "British": 0.0164, "EastAs...              so
# 230  {"African": 0.0103, "British": 0.0225, "EastAs...              so
# 231  {"African": 0.0423, "British": 0.0403, "EastAs...              so
# 232  {"African": 0.0456, "British": 0.1602, "EastAs...              so
#
#     langdetect_lang_name langdetect_prob  country_lang_comp  \
# 228               Somali             1.0                  0
# 229               Somali             1.0                  0
# 230               Somali             1.0                  0
# 231               Somali             1.0                  0
# 232               Somali             1.0                  0
#
#      hunspell_orig_known  hunspell_latin_known  pysc_orig_known  \
# 228                    1                     1                0
# 229                    0                     0                0
# 230                    0                     0                0
# 231                    0                     0                0
# 232                    0                     0                0
#
#      pysc_latin_known
# 228                 0
# 229                 0
# 230                 0
# 231                 0
# 232                 0
#
# [5 rows x 21 columns]

# %%
df_single_word["name_script"].head(5)
# Out:
# 164    Latin
# 165    Latin
# 166    Latin
# 167    Latin
# 168    Latin
# 169    Latin
# 170    Latin
# 172    Latin
# 173    Latin
# 174    Latin
# 175    Latin
# 176    Latin
# 177    Latin
# 178    Latin
# 179    Latin
# 180    Latin
# 181    Latin
# 182    Latin
# 183    Latin
# 184    Latin
# 185    Latin
# 186    Latin
# 187    Latin
# 188    Latin
# 189    Latin
# 190    Latin
# 191    Latin
# 192    Latin
# 193    Latin
# 194    Latin
# 195    Latin
# 196    Latin
# 197    Latin
# 198    Latin
# 199    Latin
# 200    Latin
# 201    Latin
# 202    Latin
# 203    Latin
# 204    Latin
# 205    Latin
# 206    Latin
# 207    Latin
# 209    Latin
# 210    Latin
# 211    Latin
# 213    Latin
# 214    Latin
# 215    Latin
# 216    Latin
# Name: name_script, dtype: object
